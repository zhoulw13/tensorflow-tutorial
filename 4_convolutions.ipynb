# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (500000, 28, 28) (500000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (500000, 28, 28, 1) (500000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.747000
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.855628
# Minibatch accuracy: 43.8%
# Validation accuracy: 41.8%
# Minibatch loss at step 100: 1.716804
# Minibatch accuracy: 56.2%
# Validation accuracy: 66.8%
# Minibatch loss at step 150: 1.295588
# Minibatch accuracy: 56.2%
# Validation accuracy: 69.9%
# Minibatch loss at step 200: 0.763714
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.5%
# Minibatch loss at step 250: 0.278898
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.2%
# Minibatch loss at step 300: 0.380828
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.1%
# Minibatch loss at step 350: 0.667963
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.6%
# Minibatch loss at step 400: 0.367790
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 450: 1.135941
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 500: 0.796694
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.6%
# Minibatch loss at step 550: 0.603615
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.8%
# Minibatch loss at step 600: 0.679935
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 650: 0.106090
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.4%
# Minibatch loss at step 700: 0.436579
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.9%
# Minibatch loss at step 750: 0.574503
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.3%
# Minibatch loss at step 800: 0.697971
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.2%
# Minibatch loss at step 850: 0.103132
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 900: 0.583756
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 950: 0.573934
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# Minibatch loss at step 1000: 0.373160
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.0%
# Test accuracy: 90.0%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64
keep_prob = 0.5

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

  global_step = tf.Variable(0, trainable=False)  # count the number of steps taken.
  learning_rate = tf.train.exponential_decay(0.05, global_step, 4000, 0.65, staircase=True)
  
  # Model.
  def model(data, train=False):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    conv = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    
    if train:
        hidden = tf.nn.dropout(hidden, keep_prob)
        
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
    conv = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    
    if train:
        hidden = tf.nn.dropout(hidden, keep_prob)
    
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.421100
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.295459
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.4%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-b716b78361f2> in <module>()
#      10     feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
#      11     _, l, predictions = session.run(
# ---> 12       [optimizer, loss, train_prediction], feed_dict=feed_dict)
#      13     if (step % 50 == 0):
#      14       print('Minibatch loss at step %d: %f' % (step, l))
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     708     try:
#     709       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 710                          run_metadata_ptr)
#     711       if run_metadata:
#     712         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     906     if final_fetches or final_targets:
#     907       results = self._do_run(handle, final_targets, final_fetches,
# --> 908                              feed_dict_string, options, run_metadata)
#     909     else:
#     910       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     956     if handle is None:
#     957       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 958                            target_list, options, run_metadata)
#     959     else:
#     960       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     963   def _do_call(self, fn, *args):
#     964     try:
# --> 965       return fn(*args)
#     966     except errors.OpError as e:
#     967       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     945         return tf_session.TF_Run(session, options,
#     946                                  feed_dict, fetch_list, target_list,
# --> 947                                  status, run_metadata)
#     948
#     949     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 64
patch_size = 5
depth1 = 6
depth2 = 16
num_hidden = 512
#num_hidden2 = 84
keep_prob = 0.5

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth1], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth1]))
    
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth1, depth2], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth2]))
    
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth2, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
  '''
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden1, num_hidden2], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden2]))
  '''

  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
    
  global_step = tf.Variable(0, trainable=False)  # count the number of steps taken.
  learning_rate = tf.train.exponential_decay(0.05, global_step, 4000, 0.65, staircase=True)
  
  # Model.
  def model(data, train=False):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    conv = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    
    conv = tf.nn.conv2d(conv, layer2_weights, [1, 1, 1, 1], padding='SAME')
    conv = tf.nn.relu(conv + layer2_biases)
    conv = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    
    shape = conv.get_shape().as_list()
    reshape = tf.reshape(conv, [shape[0], shape[1] * shape[2] * shape[3]])
    conv = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    
    if train:
        conv = tf.nn.dropout(conv, keep_prob)
    
    return tf.matmul(conv, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset, True)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

  regularizers = (tf.nn.l2_loss(layer3_weights) + tf.nn.l2_loss(layer3_biases) +
                  tf.nn.l2_loss(layer4_weights) + tf.nn.l2_loss(layer4_biases))
  loss += 5e-4 * regularizers
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 50001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 10.580288
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.049358
# Minibatch accuracy: 59.4%
# Validation accuracy: 73.7%
# Minibatch loss at step 100: 1.728020
# Minibatch accuracy: 67.2%
# Validation accuracy: 78.2%
# Minibatch loss at step 150: 1.745714
# Minibatch accuracy: 76.6%
# Validation accuracy: 81.4%
# Minibatch loss at step 200: 1.496118
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.6%
# Minibatch loss at step 250: 1.851144
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 300: 1.851034
# Minibatch accuracy: 76.6%
# Validation accuracy: 82.2%
# Minibatch loss at step 350: 1.630449
# Minibatch accuracy: 73.4%
# Validation accuracy: 83.1%
# Minibatch loss at step 400: 1.582241
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.3%
# Minibatch loss at step 450: 1.654899
# Minibatch accuracy: 71.9%
# Validation accuracy: 83.1%
# Minibatch loss at step 500: 1.613991
# Minibatch accuracy: 76.6%
# Validation accuracy: 84.1%
# Minibatch loss at step 550: 1.443091
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.2%
# Minibatch loss at step 600: 1.466209
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.3%
# Minibatch loss at step 650: 1.523809
# Minibatch accuracy: 82.8%
# Validation accuracy: 84.4%
# Minibatch loss at step 700: 1.618568
# Minibatch accuracy: 76.6%
# Validation accuracy: 84.6%
# Minibatch loss at step 750: 1.338537
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.8%
# Minibatch loss at step 800: 1.463225
# Minibatch accuracy: 78.1%
# Validation accuracy: 84.9%
# Minibatch loss at step 850: 1.678452
# Minibatch accuracy: 76.6%
# Validation accuracy: 85.2%
# Minibatch loss at step 900: 1.289281
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.0%
# Minibatch loss at step 950: 1.427693
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.5%
# Minibatch loss at step 1000: 1.438710
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.4%
# Minibatch loss at step 1050: 1.381665
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 1100: 1.375851
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.9%
# Minibatch loss at step 1150: 1.473838
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.8%
# Minibatch loss at step 1200: 1.397532
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.2%
# Minibatch loss at step 1250: 1.286532
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.1%
# Minibatch loss at step 1300: 1.372734
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.9%
# Minibatch loss at step 1350: 1.212081
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.1%
# Minibatch loss at step 1400: 1.305559
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.2%
# Minibatch loss at step 1450: 1.263156
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.7%
# Minibatch loss at step 1500: 1.075229
# Minibatch accuracy: 92.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 1550: 1.210736
# Minibatch accuracy: 92.2%
# Validation accuracy: 86.7%
# Minibatch loss at step 1600: 1.186093
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.5%
# Minibatch loss at step 1650: 1.399786
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.9%
# Minibatch loss at step 1700: 1.393143
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.8%
# Minibatch loss at step 1750: 1.197139
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.3%
# Minibatch loss at step 1800: 1.179287
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.0%
# Minibatch loss at step 1850: 1.279536
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.8%
# Minibatch loss at step 1900: 1.149389
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 1950: 1.289830
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 2000: 1.353196
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.2%
# Minibatch loss at step 2050: 1.365336
# Minibatch accuracy: 82.8%
# Validation accuracy: 86.9%
# Minibatch loss at step 2100: 1.272152
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.2%
# Minibatch loss at step 2150: 1.103818
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 2200: 1.287821
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.3%
# Minibatch loss at step 2250: 1.254658
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.0%
# Minibatch loss at step 2300: 1.374715
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 2350: 1.228267
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 2400: 1.267185
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 2450: 1.254630
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.3%
# Minibatch loss at step 2500: 1.216538
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 2550: 1.177449
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 2600: 1.145614
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.4%
# Minibatch loss at step 2650: 1.454903
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.5%
# Minibatch loss at step 2700: 1.150364
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 2750: 1.139689
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.0%
# Minibatch loss at step 2800: 1.132948
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.7%
# Minibatch loss at step 2850: 1.107475
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.5%
# Minibatch loss at step 2900: 1.243894
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.6%
# Minibatch loss at step 2950: 1.178062
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.5%
# Minibatch loss at step 3000: 1.183684
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.7%
# Minibatch loss at step 3050: 1.452529
# Minibatch accuracy: 79.7%
# Validation accuracy: 88.1%
# Minibatch loss at step 3100: 1.538392
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.0%
# Minibatch loss at step 3150: 1.309848
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.8%
# Minibatch loss at step 3200: 1.100700
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 3250: 1.198125
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.3%
# Minibatch loss at step 3300: 1.086053
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.8%
# Minibatch loss at step 3350: 1.400161
# Minibatch accuracy: 78.1%
# Validation accuracy: 87.7%
# Minibatch loss at step 3400: 1.208006
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.2%
# Minibatch loss at step 3450: 1.676287
# Minibatch accuracy: 71.9%
# Validation accuracy: 87.9%
# Minibatch loss at step 3500: 1.202436
# Minibatch accuracy: 82.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 3550: 1.096983
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.2%
# Minibatch loss at step 3600: 1.275584
# Minibatch accuracy: 82.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 3650: 1.077157
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.2%
# Minibatch loss at step 3700: 0.964900
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 3750: 1.454409
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.1%
# Minibatch loss at step 3800: 1.231536
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.3%
# Minibatch loss at step 3850: 1.300150
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 3900: 1.094400
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.3%
# Minibatch loss at step 3950: 0.954183
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 4000: 1.258754
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 4050: 1.365528
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.6%
# Minibatch loss at step 4100: 1.365612
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.6%
# Minibatch loss at step 4150: 1.251026
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.6%
# Minibatch loss at step 4200: 1.132263
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.5%
# Minibatch loss at step 4250: 1.268548
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 4300: 0.992047
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 4350: 1.111984
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.6%
# Minibatch loss at step 4400: 1.382127
# Minibatch accuracy: 82.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 4450: 1.198814
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.5%
# Minibatch loss at step 4500: 1.213279
# Minibatch accuracy: 82.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 4550: 1.148073
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.8%
# Minibatch loss at step 4600: 1.169595
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.6%
# Minibatch loss at step 4650: 1.450969
# Minibatch accuracy: 78.1%
# Validation accuracy: 88.7%
# Minibatch loss at step 4700: 1.360357
# Minibatch accuracy: 73.4%
# Validation accuracy: 88.5%
# Minibatch loss at step 4750: 1.389371
# Minibatch accuracy: 78.1%
# Validation accuracy: 88.7%
# Minibatch loss at step 4800: 0.944192
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 4850: 1.221948
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.6%
# Minibatch loss at step 4900: 1.156041
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 4950: 1.107272
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 5000: 1.321267
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.8%
# Minibatch loss at step 5050: 1.246723
# Minibatch accuracy: 82.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 5100: 1.205764
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.9%
# Minibatch loss at step 5150: 1.311401
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.9%
# Minibatch loss at step 5200: 1.027204
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 5250: 1.100501
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# Minibatch loss at step 5300: 1.157287
# Minibatch accuracy: 82.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 5350: 1.133927
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.8%
# Minibatch loss at step 5400: 0.994273
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 5450: 1.255962
# Minibatch accuracy: 82.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 5500: 1.046341
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.6%
# Minibatch loss at step 5550: 1.025125
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 5600: 1.506169
# Minibatch accuracy: 76.6%
# Validation accuracy: 89.0%
# Minibatch loss at step 5650: 1.085084
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 5700: 1.129256
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.0%
# Minibatch loss at step 5750: 1.026397
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 5800: 0.943008
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 5850: 1.046845
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.0%
# Minibatch loss at step 5900: 1.363779
# Minibatch accuracy: 79.7%
# Validation accuracy: 89.3%
# Minibatch loss at step 5950: 1.189728
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.0%
# Minibatch loss at step 6000: 1.069382
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 6050: 1.023578
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.1%
# Minibatch loss at step 6100: 1.103334
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.3%
# Minibatch loss at step 6150: 1.050323
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# Minibatch loss at step 6200: 1.302360
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.3%
# Minibatch loss at step 6250: 1.418873
# Minibatch accuracy: 79.7%
# Validation accuracy: 89.3%
# Minibatch loss at step 6300: 1.216569
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.2%
# Minibatch loss at step 6350: 0.978946
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.3%
# Minibatch loss at step 6400: 0.940076
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.9%
# Minibatch loss at step 6450: 1.190793
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.1%
# Minibatch loss at step 6500: 1.046809
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 6550: 1.274689
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.9%
# Minibatch loss at step 6600: 1.014538
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.2%
# Minibatch loss at step 6650: 1.179520
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.1%
# Minibatch loss at step 6700: 0.931321
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.2%
# Minibatch loss at step 6750: 1.263850
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.4%
# Minibatch loss at step 6800: 1.111591
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.5%
# Minibatch loss at step 6850: 1.342337
# Minibatch accuracy: 78.1%
# Validation accuracy: 89.3%
# Minibatch loss at step 6900: 1.246202
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.2%
# Minibatch loss at step 6950: 1.038883
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.3%
# Minibatch loss at step 7000: 1.125487
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.5%
# Minibatch loss at step 7050: 1.065204
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.3%
# Minibatch loss at step 7100: 1.029786
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.4%
# Minibatch loss at step 7150: 1.111743
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.2%
# Minibatch loss at step 7200: 1.034782
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.5%
# Minibatch loss at step 7250: 0.918701
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# Minibatch loss at step 7300: 1.003084
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# Minibatch loss at step 7350: 1.203163
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.6%
# Minibatch loss at step 7400: 1.079883
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.5%
# Minibatch loss at step 7450: 1.088078
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.4%
# Minibatch loss at step 7500: 1.026651
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.7%
# Minibatch loss at step 7550: 0.987553
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 7600: 0.915622
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.5%
# Minibatch loss at step 7650: 1.059193
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 7700: 1.003384
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.5%
# Minibatch loss at step 7750: 1.338625
# Minibatch accuracy: 78.1%
# Validation accuracy: 89.4%
# Minibatch loss at step 7800: 0.944875
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.6%
# Minibatch loss at step 7850: 1.149626
# Minibatch accuracy: 79.7%
# Validation accuracy: 89.5%
# Minibatch loss at step 7900: 1.027993
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 7950: 1.293702
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.5%
# Minibatch loss at step 8000: 0.856225
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 8050: 1.081465
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.5%
# Minibatch loss at step 8100: 0.947281
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.6%
# Minibatch loss at step 8150: 1.154799
# Minibatch accuracy: 82.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 8200: 1.062253
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 8250: 1.076025
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.6%
# Minibatch loss at step 8300: 1.033950
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 8350: 0.963275
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.5%
# Minibatch loss at step 8400: 0.940195
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.5%
# Minibatch loss at step 8450: 1.117195
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.7%
# Minibatch loss at step 8500: 0.971851
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 8550: 1.064790
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.7%
# Minibatch loss at step 8600: 1.140507
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.7%
# Minibatch loss at step 8650: 1.148794
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.6%
# Minibatch loss at step 8700: 1.112655
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.9%
# Minibatch loss at step 8750: 0.880722
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.9%
# Minibatch loss at step 8800: 1.023674
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.8%
# Minibatch loss at step 8850: 0.901686
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.8%
# Minibatch loss at step 8900: 1.088894
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 8950: 0.942270
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 9000: 0.964300
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.7%
# Minibatch loss at step 9050: 1.185676
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.9%
# Minibatch loss at step 9100: 0.809605
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.7%
# Minibatch loss at step 9150: 1.003439
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 9200: 0.962958
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 9250: 1.149343
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 9300: 0.932887
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.7%
# Minibatch loss at step 9350: 0.994420
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 9400: 0.911035
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 9450: 0.939481
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.8%
# Minibatch loss at step 9500: 1.036593
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.7%
# Minibatch loss at step 9550: 1.250414
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.7%
# Minibatch loss at step 9600: 0.937198
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.7%
# Minibatch loss at step 9650: 0.970043
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 9700: 1.054864
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 9750: 1.173431
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.8%
# Minibatch loss at step 9800: 1.051452
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.8%
# Minibatch loss at step 9850: 1.080869
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.9%
# Minibatch loss at step 9900: 0.995416
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 9950: 1.065140
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.8%
# Minibatch loss at step 10000: 1.189134
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.8%
# Minibatch loss at step 10050: 1.078633
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 10100: 0.968989
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.9%
# Minibatch loss at step 10150: 0.960973
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 10200: 0.961880
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 10250: 0.951072
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 10300: 0.983351
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.7%
# Minibatch loss at step 10350: 0.843014
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 10400: 0.891634
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.9%
# Minibatch loss at step 10450: 0.975360
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.8%
# Minibatch loss at step 10500: 1.027098
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.8%
# Minibatch loss at step 10550: 0.955796
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 10600: 1.077856
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.9%
# Minibatch loss at step 10650: 0.858742
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.9%
# Minibatch loss at step 10700: 0.938259
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.7%
# Minibatch loss at step 10750: 1.023969
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.7%
# Minibatch loss at step 10800: 1.103584
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 10850: 1.183304
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.9%
# Minibatch loss at step 10900: 0.941340
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.7%
# Minibatch loss at step 10950: 0.888473
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.8%
# Minibatch loss at step 11000: 1.350788
# Minibatch accuracy: 79.7%
# Validation accuracy: 89.7%
# Minibatch loss at step 11050: 1.184839
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.7%
# Minibatch loss at step 11100: 1.008319
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.7%
# Minibatch loss at step 11150: 0.865308
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.7%
# Minibatch loss at step 11200: 1.178720
# Minibatch accuracy: 82.8%
# Validation accuracy: 89.9%
# Minibatch loss at step 11250: 0.965887
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.0%
# Minibatch loss at step 11300: 1.083594
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 11350: 1.109611
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.7%
# Minibatch loss at step 11400: 1.031483
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.9%
# Minibatch loss at step 11450: 1.034630
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.8%
# Minibatch loss at step 11500: 0.937959
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.0%
# Minibatch loss at step 11550: 0.921853
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.9%
# Minibatch loss at step 11600: 1.032500
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.9%
# Minibatch loss at step 11650: 0.691362
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.9%
# Minibatch loss at step 11700: 1.196789
# Minibatch accuracy: 82.8%
# Validation accuracy: 89.9%
# Minibatch loss at step 11750: 0.779741
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# Minibatch loss at step 11800: 0.974660
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 11850: 0.835852
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# Minibatch loss at step 11900: 0.890581
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 11950: 0.830472
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# Minibatch loss at step 12000: 0.903595
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.8%
# Minibatch loss at step 12050: 1.085657
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.8%
# Minibatch loss at step 12100: 0.958048
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.8%
# Minibatch loss at step 12150: 0.887732
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.0%
# Minibatch loss at step 12200: 1.042651
# Minibatch accuracy: 82.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 12250: 0.907825
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.0%
# Minibatch loss at step 12300: 1.002141
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.9%
# Minibatch loss at step 12350: 0.927330
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.9%
# Minibatch loss at step 12400: 1.151290
# Minibatch accuracy: 82.8%
# Validation accuracy: 89.9%
# Minibatch loss at step 12450: 0.871051
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.9%
# Minibatch loss at step 12500: 0.914360
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.1%
# Minibatch loss at step 12550: 0.932953
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.9%
# Minibatch loss at step 12600: 1.107278
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.1%
# Minibatch loss at step 12650: 0.847483
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.0%
# Minibatch loss at step 12700: 0.841713
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.1%
# Minibatch loss at step 12750: 0.966458
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.9%
# Minibatch loss at step 12800: 0.892024
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 12850: 1.164649
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.1%
# Minibatch loss at step 12900: 1.110793
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.1%
# Minibatch loss at step 12950: 0.854565
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 13000: 0.844823
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.0%
# Minibatch loss at step 13050: 1.007876
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.1%
# Minibatch loss at step 13100: 1.019085
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.0%
# Minibatch loss at step 13150: 0.803279
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 13200: 1.117939
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.1%
# Minibatch loss at step 13250: 0.890519
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 13300: 1.032527
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.9%
# Minibatch loss at step 13350: 0.877728
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# Minibatch loss at step 13400: 0.888939
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.9%
# Minibatch loss at step 13450: 1.195072
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.0%
# Minibatch loss at step 13500: 1.132124
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 13550: 0.981991
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.9%
# Minibatch loss at step 13600: 0.995811
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.9%
# Minibatch loss at step 13650: 0.914312
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.0%
# Minibatch loss at step 13700: 0.855881
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.1%
# Minibatch loss at step 13750: 1.112078
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 13800: 0.798538
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.2%
# Minibatch loss at step 13850: 0.857723
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 13900: 0.931559
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.0%
# Minibatch loss at step 13950: 0.969096
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.0%
# Minibatch loss at step 14000: 1.055615
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.1%
# Minibatch loss at step 14050: 0.845683
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 14100: 0.834065
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.1%
# Minibatch loss at step 14150: 0.990406
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.1%
# Minibatch loss at step 14200: 0.720022
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.2%
# Minibatch loss at step 14250: 0.957522
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.2%
# Minibatch loss at step 14300: 0.901680
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.3%
# Minibatch loss at step 14350: 0.995049
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 14400: 0.724898
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.1%
# Minibatch loss at step 14450: 1.187515
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.1%
# Minibatch loss at step 14500: 1.260053
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 14550: 1.248581
# Minibatch accuracy: 78.1%
# Validation accuracy: 90.1%
# Minibatch loss at step 14600: 0.868630
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.0%
# Minibatch loss at step 14650: 0.950373
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.0%
# Minibatch loss at step 14700: 0.883751
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.0%
# Minibatch loss at step 14750: 1.094672
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.1%
# Minibatch loss at step 14800: 0.920926
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.0%
# Minibatch loss at step 14850: 1.131454
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.1%
# Minibatch loss at step 14900: 1.025030
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 14950: 1.021580
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 15000: 0.905608
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.1%
# Minibatch loss at step 15050: 1.065374
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# Minibatch loss at step 15100: 0.862735
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.2%
# Minibatch loss at step 15150: 0.870285
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# Minibatch loss at step 15200: 0.824183
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# Minibatch loss at step 15250: 1.002359
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.1%
# Minibatch loss at step 15300: 1.039111
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.1%
# Minibatch loss at step 15350: 0.919287
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.2%
# Minibatch loss at step 15400: 0.873409
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.1%
# Minibatch loss at step 15450: 0.812540
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.0%
# Minibatch loss at step 15500: 0.822375
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
# Minibatch loss at step 15550: 0.923921
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.0%
# Minibatch loss at step 15600: 0.847806
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# Minibatch loss at step 15650: 0.779025
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.1%
# Minibatch loss at step 15700: 0.950437
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.1%
# Minibatch loss at step 15750: 0.876715
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# Minibatch loss at step 15800: 0.868955
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.1%
# Minibatch loss at step 15850: 0.832227
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# Minibatch loss at step 15900: 0.822163
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.2%
# Minibatch loss at step 15950: 0.965666
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.1%
# Minibatch loss at step 16000: 1.026701
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 16050: 0.912507
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.1%
# Minibatch loss at step 16100: 1.068275
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.2%
# Minibatch loss at step 16150: 0.709217
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.3%
# Minibatch loss at step 16200: 1.048917
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 16250: 0.787873
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.0%
# Minibatch loss at step 16300: 1.050472
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.1%
# Minibatch loss at step 16350: 0.978606
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.1%
# Minibatch loss at step 16400: 0.919435
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 16450: 0.866102
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 16500: 0.870127
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
# Minibatch loss at step 16550: 0.870878
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
# Minibatch loss at step 16600: 0.818190
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 16650: 0.854823
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 16700: 1.113808
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.2%
# Minibatch loss at step 16750: 1.105703
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.2%
# Minibatch loss at step 16800: 1.016611
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 16850: 1.094172
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.3%
# Minibatch loss at step 16900: 0.958571
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 16950: 0.931739
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 17000: 0.928299
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 17050: 0.903217
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 17100: 0.792632
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 17150: 0.987389
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 17200: 0.703390
# Minibatch accuracy: 98.4%
# Validation accuracy: 90.2%
# Minibatch loss at step 17250: 0.633800
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# Minibatch loss at step 17300: 1.042280
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 17350: 0.794736
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.3%
# Minibatch loss at step 17400: 0.853540
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.1%
# Minibatch loss at step 17450: 0.880630
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.1%
# Minibatch loss at step 17500: 1.179075
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.2%
# Minibatch loss at step 17550: 0.910442
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.3%
# Minibatch loss at step 17600: 0.811990
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
# Minibatch loss at step 17650: 0.779322
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
# Minibatch loss at step 17700: 0.965412
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.1%
# Minibatch loss at step 17750: 0.937136
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.1%
# Minibatch loss at step 17800: 0.802083
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 17850: 0.738809
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.2%
# Minibatch loss at step 17900: 1.013998
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 17950: 0.794650
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 18000: 0.866012
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 18050: 0.786026
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.1%
# Minibatch loss at step 18100: 0.844138
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.1%
# Minibatch loss at step 18150: 0.847180
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 18200: 0.887613
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 18250: 1.039389
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 18300: 1.013289
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.2%
# Minibatch loss at step 18350: 0.918349
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 18400: 0.932251
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 18450: 0.961825
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 18500: 0.905732
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.1%
# Minibatch loss at step 18550: 1.036398
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.2%
# Minibatch loss at step 18600: 0.898204
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 18650: 0.829258
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.3%
# Minibatch loss at step 18700: 0.859440
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 18750: 0.852989
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 18800: 0.993457
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.3%
# Minibatch loss at step 18850: 1.016969
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 18900: 0.744607
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
# Minibatch loss at step 18950: 1.150234
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 19000: 0.903881
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 19050: 0.855958
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.4%
# Minibatch loss at step 19100: 1.112667
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.4%
# Minibatch loss at step 19150: 1.090300
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 19200: 0.934984
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 19250: 0.860718
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 19300: 0.845595
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.3%
# Minibatch loss at step 19350: 1.083202
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.1%
# Minibatch loss at step 19400: 1.062012
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.3%
# Minibatch loss at step 19450: 0.822515
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 19500: 0.867696
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 19550: 0.897682
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 19600: 0.952923
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 19650: 0.971495
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 19700: 1.094869
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.1%
# Minibatch loss at step 19750: 0.962178
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 19800: 0.892659
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 19850: 0.818454
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 19900: 0.845377
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 19950: 0.870540
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 20000: 0.805825
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 20050: 1.143960
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.3%
# Minibatch loss at step 20100: 0.938926
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.3%
# Minibatch loss at step 20150: 1.036537
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.3%
# Minibatch loss at step 20200: 0.882720
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.3%
# Minibatch loss at step 20250: 1.209819
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.3%
# Minibatch loss at step 20300: 0.964477
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 20350: 0.892887
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.3%
# Minibatch loss at step 20400: 1.061319
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.3%
# Minibatch loss at step 20450: 0.965774
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 20500: 0.866268
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.3%
# Minibatch loss at step 20550: 0.935948
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 20600: 0.808378
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.3%
# Minibatch loss at step 20650: 0.968982
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.4%
# Minibatch loss at step 20700: 0.991997
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 20750: 1.135792
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 20800: 0.920503
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.3%
# Minibatch loss at step 20850: 0.865381
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
# Minibatch loss at step 20900: 0.941536
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 20950: 0.979324
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.2%
# Minibatch loss at step 21000: 0.786565
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 21050: 0.868362
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 21100: 1.076398
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 21150: 1.036117
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 21200: 0.962911
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 21250: 0.868556
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 21300: 0.822074
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.3%
# Minibatch loss at step 21350: 0.898209
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.4%
# Minibatch loss at step 21400: 0.863289
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.3%
# Minibatch loss at step 21450: 0.865035
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.4%
# Minibatch loss at step 21500: 0.784064
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 21550: 0.807043
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.4%
# Minibatch loss at step 21600: 0.972649
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.4%
# Minibatch loss at step 21650: 1.225239
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.4%
# Minibatch loss at step 21700: 0.929500
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.3%
# Minibatch loss at step 21750: 1.033477
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.4%
# Minibatch loss at step 21800: 0.836894
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 21850: 0.822835
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.3%
# Minibatch loss at step 21900: 0.997234
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.3%
# Minibatch loss at step 21950: 1.046665
# Minibatch accuracy: 79.7%
# Validation accuracy: 90.4%
# Minibatch loss at step 22000: 0.980680
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 22050: 0.713695
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.4%
# Minibatch loss at step 22100: 1.060990
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 22150: 0.747828
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.4%
# Minibatch loss at step 22200: 0.857760
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.4%
# Minibatch loss at step 22250: 0.951910
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.4%
# Minibatch loss at step 22300: 0.922696
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.4%
# Minibatch loss at step 22350: 0.853113
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.4%
# Minibatch loss at step 22400: 0.833048
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.4%
# Minibatch loss at step 22450: 0.911040
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.4%
# Minibatch loss at step 22500: 0.922488
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.4%
# Minibatch loss at step 22550: 0.846193
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 22600: 0.845324
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.4%
# Minibatch loss at step 22650: 0.967804
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.4%
# Minibatch loss at step 22700: 0.787982
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.4%
# Minibatch loss at step 22750: 0.972547
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.4%
# Minibatch loss at step 22800: 0.814101
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 22850: 0.727167
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 22900: 0.911484
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 22950: 0.855003
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.4%
# Minibatch loss at step 23000: 0.959251
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.4%
# Minibatch loss at step 23050: 0.833424
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.4%
# Minibatch loss at step 23100: 0.856241
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 23150: 1.186693
# Minibatch accuracy: 79.7%
# Validation accuracy: 90.3%
# Minibatch loss at step 23200: 0.832275
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.4%
# Minibatch loss at step 23250: 0.933074
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.3%
# Minibatch loss at step 23300: 0.942018
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 23350: 0.722632
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 23400: 0.850938
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 23450: 0.811674
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.4%
# Minibatch loss at step 23500: 0.934697
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.4%
# Minibatch loss at step 23550: 0.809209
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 23600: 0.880886
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.4%
# Minibatch loss at step 23650: 0.877800
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.4%
# Minibatch loss at step 23700: 0.840197
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.4%
# Minibatch loss at step 23750: 0.850480
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.4%
# Minibatch loss at step 23800: 0.774562
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.4%
# Minibatch loss at step 23850: 0.891266
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.3%
# Minibatch loss at step 23900: 0.759463
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.4%
# Minibatch loss at step 23950: 1.011561
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.4%
# Minibatch loss at step 24000: 0.969302
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 24050: 0.834432
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.4%
# Minibatch loss at step 24100: 0.931724
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 24150: 0.823817
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.4%
# Minibatch loss at step 24200: 1.005339
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.5%
# Minibatch loss at step 24250: 0.865333
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.4%
# Minibatch loss at step 24300: 0.776446
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 24350: 0.867229
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 24400: 0.800958
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.4%
# Minibatch loss at step 24450: 0.945575
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 24500: 0.872345
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 24550: 0.980810
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.4%
# Minibatch loss at step 24600: 0.856247
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 24650: 0.998566
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.5%
# Minibatch loss at step 24700: 1.063921
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 24750: 1.019827
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 24800: 0.758147
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.4%
# Minibatch loss at step 24850: 0.849717
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 24900: 0.896958
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 24950: 0.846147
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.4%
# Minibatch loss at step 25000: 1.001551
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.4%
# Minibatch loss at step 25050: 0.745328
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 25100: 0.888888
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 25150: 0.764053
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.4%
# Minibatch loss at step 25200: 0.807283
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.4%
# Minibatch loss at step 25250: 1.014425
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.4%
# Minibatch loss at step 25300: 0.798647
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.4%
# Minibatch loss at step 25350: 0.837061
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.4%
# Minibatch loss at step 25400: 0.898170
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.4%
# Minibatch loss at step 25450: 1.027383
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.4%
# Minibatch loss at step 25500: 0.764522
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.4%
# Minibatch loss at step 25550: 0.943063
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.4%
# Minibatch loss at step 25600: 0.858762
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# Minibatch loss at step 25650: 0.921623
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.4%
# Minibatch loss at step 25700: 0.779151
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 25750: 0.836178
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# Minibatch loss at step 25800: 0.759983
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.4%
# Minibatch loss at step 25850: 0.763055
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# Minibatch loss at step 25900: 0.891001
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.4%
# Minibatch loss at step 25950: 0.843500
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 26000: 0.788781
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 26050: 0.922067
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 26100: 0.880779
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 26150: 0.821265
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# ...
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 41400: 0.847926
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.6%
# Minibatch loss at step 41450: 0.984005
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 41500: 0.817986
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 41550: 0.908050
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.6%
# Minibatch loss at step 41600: 0.835319
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.6%
# Minibatch loss at step 41650: 0.798652
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.6%
# Minibatch loss at step 41700: 0.860245
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.6%
# Minibatch loss at step 41750: 0.819401
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.6%
# Minibatch loss at step 41800: 0.689512
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.6%
# Minibatch loss at step 41850: 0.885959
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.6%
# Minibatch loss at step 41900: 0.618742
# Minibatch accuracy: 98.4%
# Validation accuracy: 90.6%
# Minibatch loss at step 41950: 0.872222
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.6%
# Minibatch loss at step 42000: 0.974518
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.6%
# Minibatch loss at step 42050: 0.965869
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.6%
# Minibatch loss at step 42100: 0.721680
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 42150: 0.986248
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.5%
# Minibatch loss at step 42200: 0.790671
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.6%
# Minibatch loss at step 42250: 1.095381
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 42300: 0.801019
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 42350: 0.720547
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 42400: 0.839725
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 42450: 0.848301
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 42500: 0.910903
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 42550: 0.810181
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 42600: 0.979722
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 42650: 0.840333
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 42700: 0.810219
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 42750: 0.852468
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 42800: 0.907170
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 42850: 0.706232
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 42900: 1.074870
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 42950: 0.751023
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 43000: 0.790836
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.6%
# Minibatch loss at step 43050: 1.000646
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.6%
# Minibatch loss at step 43100: 0.750538
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.6%
# Minibatch loss at step 43150: 0.979876
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.6%
# Minibatch loss at step 43200: 0.814903
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 43250: 0.757668
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.6%
# Minibatch loss at step 43300: 0.987785
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.6%
# Minibatch loss at step 43350: 0.725048
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.6%
# Minibatch loss at step 43400: 0.925407
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.6%
# Minibatch loss at step 43450: 0.845087
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 43500: 0.919161
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 43550: 0.731513
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 43600: 0.917692
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 43650: 0.990081
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 43700: 0.797451
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 43750: 0.946638
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 43800: 0.648810
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 43850: 0.721504
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 43900: 0.928491
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 43950: 0.934895
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.6%
# Minibatch loss at step 44000: 0.956223
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 44050: 0.869381
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 44100: 0.914918
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 44150: 0.828092
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 44200: 1.024121
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 44250: 0.960339
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 44300: 0.951561
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 44350: 0.715018
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 44400: 0.830787
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 44450: 0.795683
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 44500: 0.638759
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 44550: 0.731868
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 44600: 0.738476
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 44650: 1.039172
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.5%
# Minibatch loss at step 44700: 0.709044
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 44750: 0.891163
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 44800: 0.980983
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 44850: 0.906474
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.6%
# Minibatch loss at step 44900: 0.926019
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 44950: 0.700273
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 45000: 0.941160
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 45050: 1.019207
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.5%
# Minibatch loss at step 45100: 0.959825
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 45150: 0.778577
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 45200: 1.083873
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 45250: 0.677988
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 45300: 0.830712
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 45350: 0.884965
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 45400: 1.127846
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 45450: 1.011966
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.5%
# Minibatch loss at step 45500: 0.836098
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 45550: 0.898407
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 45600: 0.759651
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 45650: 0.834902
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 45700: 0.967838
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 45750: 0.855306
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 45800: 0.928850
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 45850: 0.872412
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 45900: 0.858671
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.6%
# Minibatch loss at step 45950: 0.753053
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 46000: 0.932810
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 46050: 0.713829
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 46100: 0.702470
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 46150: 0.880112
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 46200: 1.039245
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 46250: 1.082045
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 46300: 0.757811
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 46350: 0.893954
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.6%
# Minibatch loss at step 46400: 0.825388
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.6%
# Minibatch loss at step 46450: 0.798275
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 46500: 0.757927
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 46550: 0.814062
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.6%
# Minibatch loss at step 46600: 0.730078
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 46650: 0.877706
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.6%
# Minibatch loss at step 46700: 0.916244
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.6%
# Minibatch loss at step 46750: 0.987863
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.6%
# Minibatch loss at step 46800: 0.741639
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.6%
# Minibatch loss at step 46850: 0.817511
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 46900: 1.131724
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 46950: 1.112920
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 47000: 0.682387
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 47050: 0.883419
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.5%
# Minibatch loss at step 47100: 0.975830
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 47150: 0.836793
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 47200: 0.761110
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 47250: 0.868102
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 47300: 0.924555
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 47350: 0.821512
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 47400: 0.721992
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 47450: 0.892413
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 47500: 0.834379
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 47550: 0.808562
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 47600: 0.908981
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 47650: 1.125327
# Minibatch accuracy: 79.7%
# Validation accuracy: 90.5%
# Minibatch loss at step 47700: 0.938560
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.5%
# Minibatch loss at step 47750: 0.957223
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 47800: 0.955256
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 47850: 0.757067
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 47900: 0.936808
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 47950: 0.880249
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 48000: 1.089015
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 48050: 0.693452
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 48100: 0.778492
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.6%
# Minibatch loss at step 48150: 0.751810
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 48200: 0.775834
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 48250: 0.809817
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 48300: 0.864188
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 48350: 0.685974
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 48400: 0.720519
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 48450: 0.666058
# Minibatch accuracy: 98.4%
# Validation accuracy: 90.5%
# Minibatch loss at step 48500: 0.761080
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 48550: 0.819861
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 48600: 0.936831
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 48650: 0.741303
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 48700: 0.797985
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 48750: 0.712526
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 48800: 0.920370
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 48850: 0.759218
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 48900: 0.920290
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 48950: 0.789417
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 49000: 0.882293
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 49050: 0.809288
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 49100: 0.880916
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 49150: 0.805131
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 49200: 0.855571
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 49250: 0.946981
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 49300: 0.848116
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 49350: 0.731957
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 49400: 1.229633
# Minibatch accuracy: 76.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 49450: 0.843622
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 49500: 1.009369
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 49550: 0.744696
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 49600: 0.762179
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 49650: 0.947511
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 49700: 0.874781
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 49750: 0.715867
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 49800: 0.821962
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 49850: 1.152246
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 49900: 0.741602
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 49950: 0.965403
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 50000: 0.775081
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Test accuracy: 96.0%
